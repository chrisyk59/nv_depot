# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisyk59/nv_depot/blob/main/mental_health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ##Read CSV file from URL

# %%
import pandas as pd

url = "https://storage.googleapis.com/kagglesdsdata/datasets/7801235/12372587/mental_health_workplace_survey.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250705%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250705T201956Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

df = pd.read_csv(url)
# Out:
#    EmployeeID  Age      Gender    Country            JobRole Department  \
# 0        1001   50        Male         UK    Sales Associate         HR
# 1        1002   36        Male    Germany  Software Engineer         IT
# 2        1003   29  Non-binary      India           IT Admin         IT
# 3        1004   42        Male  Australia      HR Specialist         IT
# 4        1005   40        Male     Brazil   Customer Support    Support
#
#    YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 0              14                47         No          3.37  ...
# 1               1                59     Hybrid          7.39  ...
# 2              13                59     Hybrid          7.10  ...
# 3              15                31        Yes          4.18  ...
# 4               6                34        Yes          8.28  ...
#
#    CommuteTime  HasMentalHealthSupport  ManagerSupportScore  HasTherapyAccess  \
# ...

# %% [markdown]
# Data preprocessing

# %%
df.head(3)
# Out:
#    EmployeeID  Age      Gender  Country            JobRole Department  \
# 0        1001   50        Male       UK    Sales Associate         HR
# 1        1002   36        Male  Germany  Software Engineer         IT
# 2        1003   29  Non-binary    India           IT Admin         IT
#
#    YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 0              14                47         No          3.37  ...
# 1               1                59     Hybrid          7.39  ...
# 2              13                59     Hybrid          7.10  ...
#
#    CommuteTime  HasMentalHealthSupport  ManagerSupportScore  HasTherapyAccess  \
# 0          117                      No                 3.15               Yes
# 1            8                     Yes                 4.40               Yes
# 2           75                      No                 3.63                No
#
#    MentalHealthDaysOff  SalaryRange WorkLifeBalanceScore  TeamSize  \
# ...

# %%
df.tail()
# Out:
#       EmployeeID  Age      Gender    Country            JobRole Department  \
# 2995        3996   28      Female     Brazil  Marketing Manager      Sales
# 2996        3997   24        Male     Brazil   Customer Support  Marketing
# 2997        3998   22      Female     Canada  Marketing Manager  Marketing
# 2998        3999   57  Non-binary  Australia     Data Scientist         HR
# 2999        4000   46  Non-binary      India  Software Engineer         IT
#
#       YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 2995              18                46         No          2.86  ...
# 2996              14                31         No          2.43  ...
# 2997               0                38         No          6.87  ...
# 2998               2                41         No          3.62  ...
# 2999              17                48         No          9.77  ...
#
#       CommuteTime  HasMentalHealthSupport  ManagerSupportScore  \
# ...

# %%
df.sample(5)
# Out:
#       EmployeeID  Age      Gender Country           JobRole Department  \
# 2314        3315   51        Male  Brazil    Data Scientist      Sales
# 823         1824   34        Male      UK     HR Specialist      Sales
# 2093        3094   42  Non-binary     USA  Customer Support         HR
# 1654        2655   41        Male   India     HR Specialist  Marketing
# 2182        3183   35        Male   India          IT Admin         IT
#
#       YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 2314               9                44     Hybrid          9.54  ...
# 823                7                44        Yes          7.67  ...
# 2093               7                55        Yes          9.14  ...
# 1654               2                58        Yes          5.71  ...
# 2182              12                34     Hybrid          7.65  ...
#
#       CommuteTime  HasMentalHealthSupport  ManagerSupportScore  \
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'Country', 'JobRole', 'Department',
#        'YearsAtCompany', 'WorkHoursPerWeek', 'RemoteWork', 'BurnoutLevel',
#        'JobSatisfaction', 'StressLevel', 'ProductivityScore', 'SleepHours',
#        'PhysicalActivityHrs', 'CommuteTime', 'HasMentalHealthSupport',
#        'ManagerSupportScore', 'HasTherapyAccess', 'MentalHealthDaysOff',
#        'SalaryRange', 'WorkLifeBalanceScore', 'TeamSize', 'CareerGrowthScore',
#        'BurnoutRisk'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EmployeeID              3000 non-null   int64
#  1   Age                     3000 non-null   int64
#  2   Gender                  3000 non-null   object
#  3   Country                 3000 non-null   object
#  4   JobRole                 3000 non-null   object
#  5   Department              3000 non-null   object
#  6   YearsAtCompany          3000 non-null   int64
#  7   WorkHoursPerWeek        3000 non-null   int64
#  8   RemoteWork              3000 non-null   object
#  9   BurnoutLevel            3000 non-null   float64
#  10  JobSatisfaction         3000 non-null   float64
#  11  StressLevel             3000 non-null   float64
#  12  ProductivityScore       3000 non-null   float64
#  13  SleepHours              3000 non-null   float64
# ...

# %%
df.dtypes.value_counts()
# Out:
# float64    9
# int64      8
# object     8
# Name: count, dtype: int64

# %% [markdown]
# Display number of rows and columns.

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'Country', 'JobRole', 'Department',
#        'YearsAtCompany', 'WorkHoursPerWeek', 'RemoteWork', 'BurnoutLevel',
#        'JobSatisfaction', 'StressLevel', 'ProductivityScore', 'SleepHours',
#        'PhysicalActivityHrs', 'CommuteTime', 'HasMentalHealthSupport',
#        'ManagerSupportScore', 'HasTherapyAccess', 'MentalHealthDaysOff',
#        'SalaryRange', 'WorkLifeBalanceScore', 'TeamSize', 'CareerGrowthScore',
#        'BurnoutRisk'],
#       dtype='object')

# %%
# for display 2nd to 6th rows
display(df[1:6])

# for display starting to 10th
display(df[9:])

# for display last two rows
display(df.iloc[-2:,:])
# Out:
#    EmployeeID  Age             Gender    Country            JobRole  \
# 1        1002   36               Male    Germany  Software Engineer
# 2        1003   29         Non-binary      India           IT Admin
# 3        1004   42               Male  Australia      HR Specialist
# 4        1005   40               Male     Brazil   Customer Support
# 5        1006   44  Prefer not to say    Germany    Project Manager
#
#   Department  YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  ...  \
# 1         IT               1                59     Hybrid          7.39  ...
# 2         IT              13                59     Hybrid          7.10  ...
# 3         IT              15                31        Yes          4.18  ...
# 4    Support               6                34        Yes          8.28  ...
# 5    Support               3                58     Hybrid          3.12  ...
#
#    CommuteTime  HasMentalHealthSupport  ManagerSupportScore  HasTherapyAccess  \
# ...

# %% [markdown]
# 3.2 Data Cleaning
#
# After the explore our datasets may need to clean them for better analysis. Data coming in from multiple sources so It's possible to have an error in some values. This is where data cleaning becomes extremely important. In this section, we will delete unwanted columns, rename columns, correct appropriate data types, etc.

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'Country', 'JobRole', 'Department',
#        'YearsAtCompany', 'WorkHoursPerWeek', 'RemoteWork', 'BurnoutLevel',
#        'JobSatisfaction', 'StressLevel', 'ProductivityScore', 'SleepHours',
#        'PhysicalActivityHrs', 'CommuteTime', 'HasMentalHealthSupport',
#        'ManagerSupportScore', 'HasTherapyAccess', 'MentalHealthDaysOff',
#        'SalaryRange', 'WorkLifeBalanceScore', 'TeamSize', 'CareerGrowthScore',
#        'BurnoutRisk'],
#       dtype='object')

# %%
# Drop unwanted columns 'EmployeeID'
df.drop("EmployeeID", axis = 1, inplace = True)
df
# Out:
#       Age      Gender    Country            JobRole Department  \
# 0      50        Male         UK    Sales Associate         HR
# 1      36        Male    Germany  Software Engineer         IT
# 2      29  Non-binary      India           IT Admin         IT
# 3      42        Male  Australia      HR Specialist         IT
# 4      40        Male     Brazil   Customer Support    Support
# ...   ...         ...        ...                ...        ...
# 2995   28      Female     Brazil  Marketing Manager      Sales
# 2996   24        Male     Brazil   Customer Support  Marketing
# 2997   22      Female     Canada  Marketing Manager  Marketing
# 2998   57  Non-binary  Australia     Data Scientist         HR
# 2999   46  Non-binary      India  Software Engineer         IT
#
#       YearsAtCompany  WorkHoursPerWeek RemoteWork  BurnoutLevel  \
# 0                 14                47         No          3.37
# 1                  1                59     Hybrid          7.39
# ...

# %%
# Display duplicated entries
df.duplicated().value_counts()
# Out:
# False    3000
# Name: count, dtype: int64

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# Age                       0
# Gender                    0
# Country                   0
# JobRole                   0
# Department                0
# YearsAtCompany            0
# WorkHoursPerWeek          0
# RemoteWork                0
# BurnoutLevel              0
# JobSatisfaction           0
# StressLevel               0
# ProductivityScore         0
# SleepHours                0
# PhysicalActivityHrs       0
# CommuteTime               0
# HasMentalHealthSupport    0
# ManagerSupportScore       0
# HasTherapyAccess          0
# MentalHealthDaysOff       0
# SalaryRange               0
# WorkLifeBalanceScore      0
# TeamSize                  0
# CareerGrowthScore         0
# BurnoutRisk               0
# dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std   min    25%     50%  \
# Age                   3000.0  40.805667  11.011705  22.0  31.00  41.000
# YearsAtCompany        3000.0  10.099333   6.035032   0.0   5.00  10.000
# WorkHoursPerWeek      3000.0  44.504000   8.491526  30.0  37.00  45.000
# BurnoutLevel          3000.0   5.509137   2.574072   1.0   3.30   5.480
# JobSatisfaction       3000.0   5.437500   2.594430   1.0   3.18   5.430
# StressLevel           3000.0   5.515350   2.603610   1.0   3.26   5.495
# ProductivityScore     3000.0   5.519560   2.607610   1.0   3.28   5.490
# SleepHours            3000.0   6.539000   1.441876   4.0   5.30   6.600
# PhysicalActivityHrs   3000.0   5.030400   2.861026   0.0   2.60   5.000
# CommuteTime           3000.0  59.227000  34.809779   0.0  29.00  59.000
# ManagerSupportScore   3000.0   5.442540   2.597400   1.0   3.16   5.440
# MentalHealthDaysOff   3000.0   4.544667   2.854129   0.0   2.00   5.000
# ...

# %%
df.describe(include = object).T
# Out:
#                        count unique             top  freq
# Gender                  3000      4      Non-binary   757
# Country                 3000      7           India   464
# JobRole                 3000      8  Data Scientist   411
# Department              3000      6              HR   525
# RemoteWork              3000      3          Hybrid  1022
# HasMentalHealthSupport  3000      2              No  1531
# HasTherapyAccess        3000      2              No  1511
# SalaryRange             3000      5           100K+   640

# %%
# Calculate Mean
mean = df.Age.mean()

# Calculate Median
median = df.Age.median()

#Calculate Mode
mode = df.Age.mode().iloc[0]

# Calculate standard deviation
std = df.Age.std()

# Calculate Minimum values
min_val = df.Age.min()

# Calculate Maximum values
max_cal = df.Age.max()

print(f" Mean of Age : {mean}")
print(f" Median of Age : {median}")
print(f" Mode of Age : {mode}")
print(f" Standard deviation of Age : {std:.2f}")
print(f" Maximum of Age : {max_cal}")
print(f" Menimum of Age : {min_val}")
# Out:
#  Mean of Age : 40.80566666666667
#  Median of Age : 41.0
#  Mode of Age : 56
#  Standard deviation of Age : 11.01
#  Maximum of Age : 59
#  Menimum of Age : 22

# %%
# calculate correlation
df.select_dtypes("number").corr()
# Out:
#                            Age  YearsAtCompany  WorkHoursPerWeek  \
# Age                   1.000000       -0.027622          0.022825
# YearsAtCompany       -0.027622        1.000000          0.005341
# WorkHoursPerWeek      0.022825        0.005341          1.000000
# BurnoutLevel         -0.009468       -0.012922         -0.022458
# JobSatisfaction      -0.014901        0.029856          0.009827
# StressLevel          -0.003344       -0.027008         -0.007547
# ProductivityScore     0.019368       -0.005963         -0.041243
# SleepHours            0.028606       -0.022985         -0.013681
# PhysicalActivityHrs   0.003675       -0.005059          0.015023
# CommuteTime          -0.021495       -0.004883         -0.006960
# ManagerSupportScore  -0.019685        0.007289          0.010886
# MentalHealthDaysOff   0.031145       -0.009859          0.005757
# WorkLifeBalanceScore -0.002315        0.006605         -0.039689
# ...
